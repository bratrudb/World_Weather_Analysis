# %%
#Import Dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# %%
# Creating a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Importing the API key.
from config import weather_api_key

# %%
# URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="

query_url = (f"{url}{weather_api_key}")

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = query_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | salalah
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | kjollefjord
# Processing Record 5 of Set 1 | iberia
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | sainte-thecle
# Processing Record 8 of Set 1 | conil
# Processing Record 9 of Set 1 | canyon lake
# Processing Record 10 of Set 1 | shieli
# Processing Record 11 of Set 1 | katastarion
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | yeniseysk
# Processing Record 16 of Set 1 | abha
# Processing Record 17 of Set 1 | bakchar
# Processing Record 18 of Set 1 | fallon
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | suao
# City not found. Skipping...
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | manaus
# Processing Record 24 of Set 1 | nanortalik
# Processing Record 25 of Set 1 | craig
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | gijon
# Processing Record 29 of Set 1 | port augusta
# Processing Record 30 of Set 1 | najran
# Processing Record 31 of Set 1 | uvalde
# Processing Record 32 of Set 1 | san felipe
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | kruisfontein
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | bowen
# Processing Record 40 of Set 1 | moose factory
# Processing Record 41 of Set 1 | noumea
# Processing Record 42 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | norfolk
# Processing Record 46 of Set 1 | afyonkarahisar
# Processing Record 47 of Set 1 | tambacounda
# Processing Record 48 of Set 1 | qandala
# Processing Record 49 of Set 1 | guerrero negro
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 2 | tessalit
# Processing Record 3 of Set 2 | hobyo
# Processing Record 4 of Set 2 | bonavista
# Processing Record 5 of Set 2 | dubti
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | bacolod
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 2 | atagay
# Processing Record 15 of Set 2 | parintins
# Processing Record 16 of Set 2 | payakumbuh
# Processing Record 17 of Set 2 | olean
# Processing Record 18 of Set 2 | carmelo
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | pisco
# Processing Record 22 of Set 2 | porto franco
# Processing Record 23 of Set 2 | hope
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | namwala
# Processing Record 26 of Set 2 | sao filipe
# Processing Record 27 of Set 2 | hofn
# Processing Record 28 of Set 2 | mount isa
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | mackay
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | clyde river
# Processing Record 34 of Set 2 | ostrovnoy
# Processing Record 35 of Set 2 | dakar
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | lubango
# Processing Record 39 of Set 2 | banda aceh
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | luanda
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | piacabucu
# Processing Record 45 of Set 2 | havelock
# Processing Record 46 of Set 2 | naze
# Processing Record 47 of Set 2 | teya
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | pokosnoye
# Processing Record 50 of Set 2 | kampong cham
# Processing Record 1 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | san cristobal
# Processing Record 4 of Set 3 | lagoa
# Processing Record 5 of Set 3 | saint-pierre
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | dudinka
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 3 | bhuj
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | novouzensk
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | ayagoz
# Processing Record 15 of Set 3 | srednekolymsk
# Processing Record 16 of Set 3 | ladushkin
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | melilla
# Processing Record 19 of Set 3 | grindavik
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | svetlyy
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | artyom
# Processing Record 25 of Set 3 | cockburn town
# Processing Record 26 of Set 3 | husavik
# Processing Record 27 of Set 3 | falaleu
# City not found. Skipping...
# Processing Record 28 of Set 3 | coruripe
# Processing Record 29 of Set 3 | oktyabrskiy
# Processing Record 30 of Set 3 | margate
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | cornelio procopio
# Processing Record 33 of Set 3 | gravdal
# Processing Record 34 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | hami
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | hamilton
# Processing Record 39 of Set 3 | burica
# City not found. Skipping...
# Processing Record 40 of Set 3 | turukhansk
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | bandarbeyla
# Processing Record 44 of Set 3 | san quintin
# Processing Record 45 of Set 3 | lazarev
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | alyangula
# Processing Record 48 of Set 3 | carnarvon
# Processing Record 49 of Set 3 | bang racham
# Processing Record 50 of Set 3 | kavieng
# Processing Record 1 of Set 4 | morehead
# Processing Record 2 of Set 4 | ajdabiya
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | agnibilekrou
# Processing Record 6 of Set 4 | qaqortoq
# Processing Record 7 of Set 4 | cape town
# Processing Record 8 of Set 4 | la ronge
# Processing Record 9 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 4 | vila velha
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | havre-saint-pierre
# Processing Record 14 of Set 4 | tekeli
# Processing Record 15 of Set 4 | makat
# Processing Record 16 of Set 4 | trapani
# Processing Record 17 of Set 4 | golden
# Processing Record 18 of Set 4 | constitucion
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | marzuq
# Processing Record 21 of Set 4 | denpasar
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | praia
# Processing Record 24 of Set 4 | broome
# Processing Record 25 of Set 4 | villa maria
# Processing Record 26 of Set 4 | nishihara
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | comodoro rivadavia
# Processing Record 29 of Set 4 | eugene
# Processing Record 30 of Set 4 | atuona
# Processing Record 31 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 4 | nuuk
# Processing Record 33 of Set 4 | antofagasta
# Processing Record 34 of Set 4 | saldanha
# Processing Record 35 of Set 4 | sieradz
# Processing Record 36 of Set 4 | nizhyn
# Processing Record 37 of Set 4 | ancud
# Processing Record 38 of Set 4 | acari
# Processing Record 39 of Set 4 | bolshiye uki
# City not found. Skipping...
# Processing Record 40 of Set 4 | avarua
# Processing Record 41 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 4 | kaitangata
# Processing Record 43 of Set 4 | atasu
# Processing Record 44 of Set 4 | port hedland
# Processing Record 45 of Set 4 | izumo
# Processing Record 46 of Set 4 | spirit river
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | erenhot
# Processing Record 49 of Set 4 | tual
# Processing Record 50 of Set 4 | rabo de peixe
# Processing Record 1 of Set 5 | heishan
# Processing Record 2 of Set 5 | mpongwe
# Processing Record 3 of Set 5 | nanakuli
# Processing Record 4 of Set 5 | guia lopes da laguna
# Processing Record 5 of Set 5 | ilam
# Processing Record 6 of Set 5 | zhigansk
# Processing Record 7 of Set 5 | kalanguy
# Processing Record 8 of Set 5 | mugur-aksy
# Processing Record 9 of Set 5 | chuy
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | dingle
# Processing Record 12 of Set 5 | berlevag
# Processing Record 13 of Set 5 | paita
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | marawi
# Processing Record 16 of Set 5 | ciudad dario
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | knyaze-volkonskoye
# Processing Record 19 of Set 5 | limbang
# Processing Record 20 of Set 5 | hambantota
# Processing Record 21 of Set 5 | yar-sale
# Processing Record 22 of Set 5 | krasnoselkup
# Processing Record 23 of Set 5 | areka
# Processing Record 24 of Set 5 | el campo
# Processing Record 25 of Set 5 | buala
# Processing Record 26 of Set 5 | chokurdakh
# Processing Record 27 of Set 5 | dera ghazi khan
# Processing Record 28 of Set 5 | gravelbourg
# Processing Record 29 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 5 | pacific grove
# Processing Record 31 of Set 5 | general pico
# Processing Record 32 of Set 5 | hovd
# Processing Record 33 of Set 5 | codrington
# Processing Record 34 of Set 5 | cidreira
# Processing Record 35 of Set 5 | bathsheba
# Processing Record 36 of Set 5 | sur
# Processing Record 37 of Set 5 | mafinga
# Processing Record 38 of Set 5 | caravelas
# Processing Record 39 of Set 5 | narsaq
# Processing Record 40 of Set 5 | copiapo
# Processing Record 41 of Set 5 | katsuura
# Processing Record 42 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 5 | sovetskiy
# Processing Record 44 of Set 5 | adrar
# Processing Record 45 of Set 5 | san patricio
# Processing Record 46 of Set 5 | coihaique
# Processing Record 47 of Set 5 | lompoc
# Processing Record 48 of Set 5 | saskylakh
# Processing Record 49 of Set 5 | ludwigsfelde
# Processing Record 50 of Set 5 | brandon
# Processing Record 1 of Set 6 | saint anthony
# Processing Record 2 of Set 6 | viedma
# Processing Record 3 of Set 6 | asau
# Processing Record 4 of Set 6 | itarema
# Processing Record 5 of Set 6 | itapage
# Processing Record 6 of Set 6 | tezu
# Processing Record 7 of Set 6 | sampit
# Processing Record 8 of Set 6 | leningradskiy
# Processing Record 9 of Set 6 | georgetown
# Processing Record 10 of Set 6 | gwadar
# Processing Record 11 of Set 6 | andenes
# Processing Record 12 of Set 6 | tautira
# Processing Record 13 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 14 of Set 6 | monte cristi
# City not found. Skipping...
# Processing Record 15 of Set 6 | tuatapere
# Processing Record 16 of Set 6 | mutsu
# Processing Record 17 of Set 6 | karpuninskiy
# City not found. Skipping...
# Processing Record 18 of Set 6 | harper
# Processing Record 19 of Set 6 | yulara
# Processing Record 20 of Set 6 | lasa
# Processing Record 21 of Set 6 | westerland
# Processing Record 22 of Set 6 | cayenne
# Processing Record 23 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | anori
# Processing Record 25 of Set 6 | shingu
# Processing Record 26 of Set 6 | bengkulu
# Processing Record 27 of Set 6 | bitung
# Processing Record 28 of Set 6 | mayumba
# Processing Record 29 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 6 | jalu
# Processing Record 31 of Set 6 | chalon-sur-saone
# Processing Record 32 of Set 6 | sidvokodvo
# Processing Record 33 of Set 6 | rocha
# Processing Record 34 of Set 6 | oistins
# Processing Record 35 of Set 6 | wanning
# Processing Record 36 of Set 6 | timmins
# Processing Record 37 of Set 6 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 38 of Set 6 | polyarnyy
# Processing Record 39 of Set 6 | mildura
# Processing Record 40 of Set 6 | coahuayana
# Processing Record 41 of Set 6 | kandalaksha
# Processing Record 42 of Set 6 | isangel
# Processing Record 43 of Set 6 | sakaiminato
# Processing Record 44 of Set 6 | labuhan
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | bayir
# Processing Record 47 of Set 6 | linares
# Processing Record 48 of Set 6 | aykhal
# Processing Record 49 of Set 6 | ipixuna
# Processing Record 50 of Set 6 | hasaki
# Processing Record 1 of Set 7 | merauke
# Processing Record 2 of Set 7 | cabedelo
# Processing Record 3 of Set 7 | george
# Processing Record 4 of Set 7 | ossora
# Processing Record 5 of Set 7 | portpatrick
# City not found. Skipping...
# Processing Record 6 of Set 7 | novyy urengoy
# Processing Record 7 of Set 7 | umm kaddadah
# Processing Record 8 of Set 7 | kyabe
# Processing Record 9 of Set 7 | santa maria
# Processing Record 10 of Set 7 | berja
# Processing Record 11 of Set 7 | dongsheng
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 14 of Set 7 | souillac
# Processing Record 15 of Set 7 | yebaishou
# Processing Record 16 of Set 7 | saint-philippe
# Processing Record 17 of Set 7 | khatanga
# Processing Record 18 of Set 7 | aksu
# Processing Record 19 of Set 7 | mindelo
# Processing Record 20 of Set 7 | blagoyevo
# Processing Record 21 of Set 7 | calderitas
# Processing Record 22 of Set 7 | mmabatho
# Processing Record 23 of Set 7 | arlit
# Processing Record 24 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 7 | akom
# Processing Record 26 of Set 7 | nosy varika
# Processing Record 27 of Set 7 | te anau
# Processing Record 28 of Set 7 | turkistan
# Processing Record 29 of Set 7 | mariinsk
# Processing Record 30 of Set 7 | mount darwin
# Processing Record 31 of Set 7 | skiros
# City not found. Skipping...
# Processing Record 32 of Set 7 | aasiaat
# Processing Record 33 of Set 7 | pozhva
# Processing Record 34 of Set 7 | ciudad bolivar
# Processing Record 35 of Set 7 | suba
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | vao
# Processing Record 38 of Set 7 | ormara
# Processing Record 39 of Set 7 | taoudenni
# Processing Record 40 of Set 7 | muncar
# Processing Record 41 of Set 7 | olinda
# Processing Record 42 of Set 7 | nyahururu
# Processing Record 43 of Set 7 | rawicz
# Processing Record 44 of Set 7 | aklavik
# Processing Record 45 of Set 7 | araouane
# Processing Record 46 of Set 7 | hualmay
# Processing Record 47 of Set 7 | panama city
# Processing Record 48 of Set 7 | shchuchye
# City not found. Skipping...
# Processing Record 49 of Set 7 | norman wells
# Processing Record 50 of Set 7 | slave lake
# Processing Record 1 of Set 8 | brownsville
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | waingapu
# Processing Record 4 of Set 8 | mazamari
# Processing Record 5 of Set 8 | dennery
# Processing Record 6 of Set 8 | gamba
# Processing Record 7 of Set 8 | marrakesh
# Processing Record 8 of Set 8 | bang saphan
# Processing Record 9 of Set 8 | tashara
# Processing Record 10 of Set 8 | hervey bay
# Processing Record 11 of Set 8 | dzaoudzi
# Processing Record 12 of Set 8 | broken hill
# Processing Record 13 of Set 8 | olafsvik
# Processing Record 14 of Set 8 | ozinki
# Processing Record 15 of Set 8 | roblin
# Processing Record 16 of Set 8 | wagrowiec
# Processing Record 17 of Set 8 | zhangye
# Processing Record 18 of Set 8 | anadyr
# Processing Record 19 of Set 8 | sitka
# Processing Record 20 of Set 8 | mantua
# Processing Record 21 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 8 | scarborough
# Processing Record 23 of Set 8 | zharkent
# Processing Record 24 of Set 8 | dolni dabnik
# Processing Record 25 of Set 8 | muros
# Processing Record 26 of Set 8 | brae
# Processing Record 27 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 8 | ruian
# City not found. Skipping...
# Processing Record 29 of Set 8 | aurich
# Processing Record 30 of Set 8 | hohhot
# Processing Record 31 of Set 8 | xudat
# Processing Record 32 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 8 | praia da vitoria
# Processing Record 34 of Set 8 | kushmurun
# Processing Record 35 of Set 8 | alofi
# Processing Record 36 of Set 8 | ternate
# Processing Record 37 of Set 8 | tazovskiy
# Processing Record 38 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 39 of Set 8 | ouadda
# Processing Record 40 of Set 8 | kharitonovo
# Processing Record 41 of Set 8 | vostok
# Processing Record 42 of Set 8 | lerik
# Processing Record 43 of Set 8 | ahipara
# Processing Record 44 of Set 8 | apatity
# Processing Record 45 of Set 8 | kalmunai
# Processing Record 46 of Set 8 | starobachaty
# Processing Record 47 of Set 8 | razole
# Processing Record 48 of Set 8 | shahganj
# Processing Record 49 of Set 8 | arauca
# Processing Record 50 of Set 8 | vestmannaeyjar
# Processing Record 1 of Set 9 | ust-tsilma
# Processing Record 2 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 9 | sehithwa
# Processing Record 4 of Set 9 | kahului
# Processing Record 5 of Set 9 | kouango
# Processing Record 6 of Set 9 | cabinda
# Processing Record 7 of Set 9 | lazaro cardenas
# Processing Record 8 of Set 9 | pokhara
# Processing Record 9 of Set 9 | phangnga
# Processing Record 10 of Set 9 | pingliang
# Processing Record 11 of Set 9 | tairua
# Processing Record 12 of Set 9 | meulaboh
# Processing Record 13 of Set 9 | yazman
# Processing Record 14 of Set 9 | talaya
# Processing Record 15 of Set 9 | nortelandia
# Processing Record 16 of Set 9 | abu samrah
# Processing Record 17 of Set 9 | kitimat
# Processing Record 18 of Set 9 | olavarria
# Processing Record 19 of Set 9 | xingyi
# Processing Record 20 of Set 9 | marathon
# Processing Record 21 of Set 9 | paracuru
# Processing Record 22 of Set 9 | imbituba
# Processing Record 23 of Set 9 | aripuana
# Processing Record 24 of Set 9 | langsa
# Processing Record 25 of Set 9 | estelle
# Processing Record 26 of Set 9 | kutum
# Processing Record 27 of Set 9 | leh
# Processing Record 28 of Set 9 | fengcheng
# Processing Record 29 of Set 9 | male
# Processing Record 30 of Set 9 | pyapon
# Processing Record 31 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 9 | bosaso
# Processing Record 33 of Set 9 | quatre cocos
# Processing Record 34 of Set 9 | mahajanga
# Processing Record 35 of Set 9 | kalangala
# Processing Record 36 of Set 9 | nova vicosa
# Processing Record 37 of Set 9 | klaksvik
# Processing Record 38 of Set 9 | esil
# Processing Record 39 of Set 9 | yanam
# Processing Record 40 of Set 9 | ambilobe
# Processing Record 41 of Set 9 | damara
# Processing Record 42 of Set 9 | rolla
# Processing Record 43 of Set 9 | auki
# Processing Record 44 of Set 9 | sorland
# Processing Record 45 of Set 9 | selizharovo
# Processing Record 46 of Set 9 | vardo
# Processing Record 47 of Set 9 | mbanza-ngungu
# Processing Record 48 of Set 9 | mizdah
# Processing Record 49 of Set 9 | pilani
# Processing Record 50 of Set 9 | afsin
# Processing Record 1 of Set 10 | westport
# Processing Record 2 of Set 10 | opuwo
# Processing Record 3 of Set 10 | chihuahua
# Processing Record 4 of Set 10 | plyussa
# Processing Record 5 of Set 10 | tsalenjikha
# Processing Record 6 of Set 10 | saint george
# Processing Record 7 of Set 10 | los llanos de aridane
# Processing Record 8 of Set 10 | bilma
# Processing Record 9 of Set 10 | wum
# Processing Record 10 of Set 10 | nome
# Processing Record 11 of Set 10 | keffi
# Processing Record 12 of Set 10 | arvin
# Processing Record 13 of Set 10 | kugulta
# Processing Record 14 of Set 10 | atar
# Processing Record 15 of Set 10 | pangai
# Processing Record 16 of Set 10 | narok
# Processing Record 17 of Set 10 | miri
# Processing Record 18 of Set 10 | shebalino
# Processing Record 19 of Set 10 | port blair
# Processing Record 20 of Set 10 | ewa beach
# Processing Record 21 of Set 10 | puerto escondido
# Processing Record 22 of Set 10 | bundaberg
# Processing Record 23 of Set 10 | natal
# Processing Record 24 of Set 10 | kasongo-lunda
# Processing Record 25 of Set 10 | dakoro
# Processing Record 26 of Set 10 | douglas
# Processing Record 27 of Set 10 | mogadishu
# Processing Record 28 of Set 10 | south venice
# Processing Record 29 of Set 10 | bangsund
# Processing Record 30 of Set 10 | izhma
# Processing Record 31 of Set 10 | buenos aires
# Processing Record 32 of Set 10 | acarau
# Processing Record 33 of Set 10 | bam
# Processing Record 34 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 10 | steamboat springs
# Processing Record 36 of Set 10 | seoul
# Processing Record 37 of Set 10 | baghdad
# Processing Record 38 of Set 10 | brunico
# Processing Record 39 of Set 10 | monteagudo
# Processing Record 40 of Set 10 | flinders
# Processing Record 41 of Set 10 | santa cruz
# Processing Record 42 of Set 10 | port lincoln
# Processing Record 43 of Set 10 | maningrida
# Processing Record 44 of Set 10 | ducheng
# Processing Record 45 of Set 10 | udachnyy
# Processing Record 46 of Set 10 | uvinza
# Processing Record 47 of Set 10 | alta floresta
# Processing Record 48 of Set 10 | boyolangu
# Processing Record 49 of Set 10 | dire dawa
# Processing Record 50 of Set 10 | zhuzhou
# Processing Record 1 of Set 11 | pachino
# Processing Record 2 of Set 11 | misratah
# Processing Record 3 of Set 11 | ngunguru
# Processing Record 4 of Set 11 | shenjiamen
# Processing Record 5 of Set 11 | byron bay
# Processing Record 6 of Set 11 | north myrtle beach
# Processing Record 7 of Set 11 | abaza
# Processing Record 8 of Set 11 | beloha
# Processing Record 9 of Set 11 | issaquah
# Processing Record 10 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 11 | miyang
# Processing Record 12 of Set 11 | raudeberg
# Processing Record 13 of Set 11 | pensilvania
# Processing Record 14 of Set 11 | buarcos
# Processing Record 15 of Set 11 | touros
# Processing Record 16 of Set 11 | richards bay
# Processing Record 17 of Set 11 | bidar
# Processing Record 18 of Set 11 | skjervoy
# Processing Record 19 of Set 11 | santa isabel do rio negro
# Processing Record 20 of Set 11 | marsh harbour
# Processing Record 21 of Set 11 | ndago
# Processing Record 22 of Set 11 | baraboo
# Processing Record 23 of Set 11 | bima
# Processing Record 24 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 11 | iwanai
# Processing Record 26 of Set 11 | talnakh
# Processing Record 27 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 11 | vredendal
# Processing Record 29 of Set 11 | neuquen
# Processing Record 30 of Set 11 | atbasar
# Processing Record 31 of Set 11 | petrivka
# Processing Record 32 of Set 11 | riviere-au-renard
# Processing Record 33 of Set 11 | zhanaozen
# Processing Record 34 of Set 11 | batagay-alyta
# Processing Record 35 of Set 11 | lorengau
# Processing Record 36 of Set 11 | waitara
# Processing Record 37 of Set 11 | atambua
# Processing Record 38 of Set 11 | ornskoldsvik
# Processing Record 39 of Set 11 | ugoofaaru
# Processing Record 40 of Set 11 | taksimo
# Processing Record 41 of Set 11 | almeirim
# Processing Record 42 of Set 11 | pilar
# Processing Record 43 of Set 11 | iquique
# Processing Record 44 of Set 11 | primero de enero
# Processing Record 45 of Set 11 | irbeyskoye
# Processing Record 46 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 47 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 11 | ulladulla
# Processing Record 49 of Set 11 | camacha
# Processing Record 50 of Set 11 | emba
# Processing Record 1 of Set 12 | willmar
# Processing Record 2 of Set 12 | fort saint james
# Processing Record 3 of Set 12 | den helder
# Processing Record 4 of Set 12 | gafanha da encarnacao
# Processing Record 5 of Set 12 | ust-maya
# Processing Record 6 of Set 12 | manta
# Processing Record 7 of Set 12 | boddam
# Processing Record 8 of Set 12 | saint-paul
# Processing Record 9 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 12 | laela
# Processing Record 11 of Set 12 | oriximina
# Processing Record 12 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 13 of Set 12 | san ramon
# Processing Record 14 of Set 12 | padang
# Processing Record 15 of Set 12 | oranjemund
# Processing Record 16 of Set 12 | lardos
# Processing Record 17 of Set 12 | kondinskoye
# Processing Record 18 of Set 12 | high level
# Processing Record 19 of Set 12 | isfana
# Processing Record 20 of Set 12 | balkanabat
# Processing Record 21 of Set 12 | kwinana
# Processing Record 22 of Set 12 | san jose de buan
# Processing Record 23 of Set 12 | bardiyah
# Processing Record 24 of Set 12 | oskarshamn
# Processing Record 25 of Set 12 | wadi musa
# Processing Record 26 of Set 12 | yumen
# Processing Record 27 of Set 12 | urusha
# Processing Record 28 of Set 12 | kalmanka
# Processing Record 29 of Set 12 | veraval
# Processing Record 30 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 12 | burnie
# Processing Record 32 of Set 12 | faya
# Processing Record 33 of Set 12 | mezen
# Processing Record 34 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 37 of Set 12 | waddan
# Processing Record 38 of Set 12 | topchikha
# Processing Record 39 of Set 12 | todos santos
# Processing Record 40 of Set 12 | guadalupe y calvo
# Processing Record 41 of Set 12 | korla
# Processing Record 42 of Set 12 | mandurah
# Processing Record 43 of Set 12 | kununurra
# Processing Record 44 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 12 | west fargo
# Processing Record 46 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 12 | lavrentiya
# Processing Record 48 of Set 12 | canberra
# Processing Record 49 of Set 12 | solone
# Processing Record 50 of Set 12 | inuvik
# Processing Record 1 of Set 13 | vilhena
# Processing Record 2 of Set 13 | adre
# Processing Record 3 of Set 13 | nazareno
# Processing Record 4 of Set 13 | mineiros
# Processing Record 5 of Set 13 | mwinilunga
# Processing Record 6 of Set 13 | santa cruz cabralia
# Processing Record 7 of Set 13 | gushi
# Processing Record 8 of Set 13 | hyeres
# Processing Record 9 of Set 13 | cheremukhovo
# Processing Record 10 of Set 13 | takoradi
# Processing Record 11 of Set 13 | madang
# Processing Record 12 of Set 13 | chaah
# Processing Record 13 of Set 13 | felanitx
# Processing Record 14 of Set 13 | wuan
# Processing Record 15 of Set 13 | vanimo
# Processing Record 16 of Set 13 | kamiiso
# Processing Record 17 of Set 13 | paamiut
# Processing Record 18 of Set 13 | alma
# Processing Record 19 of Set 13 | mayo
# Processing Record 20 of Set 13 | povenets
# Processing Record 21 of Set 13 | ixtapa
# Processing Record 22 of Set 13 | gigmoto
# Processing Record 23 of Set 13 | jaguaruana
# Processing Record 24 of Set 13 | jumla
# Processing Record 25 of Set 13 | sunndalsora
# Processing Record 26 of Set 13 | ostuacan
# Processing Record 27 of Set 13 | gerash
# Processing Record 28 of Set 13 | mafeteng
# Processing Record 29 of Set 13 | sisimiut
# Processing Record 30 of Set 13 | ilaya
# Processing Record 31 of Set 13 | jundia
# Processing Record 32 of Set 13 | sungurlu
# Processing Record 33 of Set 13 | puerto baquerizo moreno
# Processing Record 34 of Set 13 | porto novo
# Processing Record 35 of Set 13 | prado
# Processing Record 36 of Set 13 | angoche
# Processing Record 37 of Set 13 | yanji
# Processing Record 38 of Set 13 | daru
# Processing Record 39 of Set 13 | at-bashi
# Processing Record 40 of Set 13 | sao joao da barra
# Processing Record 41 of Set 13 | port-gentil
# Processing Record 42 of Set 13 | tanda
# Processing Record 43 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 13 | whitecourt
# Processing Record 45 of Set 13 | nantucket
# Processing Record 46 of Set 13 | xiaoyi
# Processing Record 47 of Set 13 | tres arroyos
# Processing Record 48 of Set 13 | tsevie
# Processing Record 49 of Set 13 | bangassou
# Processing Record 50 of Set 13 | herat
# Processing Record 1 of Set 14 | bilibino
# Processing Record 2 of Set 14 | fare
# Processing Record 3 of Set 14 | sorong
# Processing Record 4 of Set 14 | matara
# Processing Record 5 of Set 14 | longyearbyen
# Processing Record 6 of Set 14 | tiarei
# Processing Record 7 of Set 14 | aquiraz
# Processing Record 8 of Set 14 | oulainen
# Processing Record 9 of Set 14 | altay
# Processing Record 10 of Set 14 | mchinji
# Processing Record 11 of Set 14 | rio grande
# Processing Record 12 of Set 14 | pizarro
# Processing Record 13 of Set 14 | umea
# Processing Record 14 of Set 14 | orgun
# City not found. Skipping...
# Processing Record 15 of Set 14 | gander
# Processing Record 16 of Set 14 | sangar
# Processing Record 17 of Set 14 | biltine
# Processing Record 18 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 14 | koboldo
# City not found. Skipping...
# Processing Record 20 of Set 14 | fort-shevchenko
# Processing Record 21 of Set 14 | lima
# Processing Record 22 of Set 14 | pula
# Processing Record 23 of Set 14 | kulhudhuffushi
# Processing Record 24 of Set 14 | college
# Processing Record 25 of Set 14 | greytown
# Processing Record 26 of Set 14 | kimbe
# Processing Record 27 of Set 14 | farmington
# Processing Record 28 of Set 14 | ketchikan
# Processing Record 29 of Set 14 | kaeo
# Processing Record 30 of Set 14 | luau
# Processing Record 31 of Set 14 | burgeo
# Processing Record 32 of Set 14 | fairbanks
# Processing Record 33 of Set 14 | baykit
# Processing Record 34 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 14 | monte patria
# Processing Record 36 of Set 14 | chernyshevsk
# Processing Record 37 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 14 | puerto del rosario
# Processing Record 39 of Set 14 | mae sai
# Processing Record 40 of Set 14 | hammerfest
# Processing Record 41 of Set 14 | aleksandrovskiy zavod
# Processing Record 42 of Set 14 | hazorasp
# Processing Record 43 of Set 14 | seybaplaya
# Processing Record 44 of Set 14 | khasan
# Processing Record 45 of Set 14 | tobol
# Processing Record 46 of Set 14 | stornoway
# Processing Record 47 of Set 14 | milazzo
# Processing Record 48 of Set 14 | bogorodskoye
# Processing Record 49 of Set 14 | namatanai
# Processing Record 50 of Set 14 | juneau
# Processing Record 1 of Set 15 | alice springs
# Processing Record 2 of Set 15 | koshurnikovo
# Processing Record 3 of Set 15 | presidente medici
# Processing Record 4 of Set 15 | tabuk
# Processing Record 5 of Set 15 | coquimbo
# Processing Record 6 of Set 15 | tabou
# Processing Record 7 of Set 15 | pontes e lacerda
# Processing Record 8 of Set 15 | nyurba
# Processing Record 9 of Set 15 | caramay
# Processing Record 10 of Set 15 | egvekinot
# Processing Record 11 of Set 15 | dongying
# Processing Record 12 of Set 15 | okha
# Processing Record 13 of Set 15 | nemours
# Processing Record 14 of Set 15 | abriaqui
# Processing Record 15 of Set 15 | kirakira
# Processing Record 16 of Set 15 | samut sakhon
# Processing Record 17 of Set 15 | half moon bay
# Processing Record 18 of Set 15 | boa vista
# Processing Record 19 of Set 15 | san policarpo
# Processing Record 20 of Set 15 | ayan
# Processing Record 21 of Set 15 | walvis bay
# Processing Record 22 of Set 15 | mana
# Processing Record 23 of Set 15 | nouakchott
# Processing Record 24 of Set 15 | kloulklubed
# Processing Record 25 of Set 15 | bonito oriental
# Processing Record 26 of Set 15 | namibe
# Processing Record 27 of Set 15 | prachin buri
# Processing Record 28 of Set 15 | soyo
# Processing Record 29 of Set 15 | ucluelet
# Processing Record 30 of Set 15 | altinho
# Processing Record 31 of Set 15 | nouadhibou
# Processing Record 32 of Set 15 | port hardy
# Processing Record 33 of Set 15 | luba
# Processing Record 34 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 35 of Set 15 | shahr-e kord
# Processing Record 36 of Set 15 | sambava
# Processing Record 37 of Set 15 | zapolyarnyy
# Processing Record 38 of Set 15 | fairfield
# Processing Record 39 of Set 15 | brandenburg
# Processing Record 40 of Set 15 | rozkishne
# Processing Record 41 of Set 15 | itaperucu
# Processing Record 42 of Set 15 | presidencia roque saenz pena
# Processing Record 43 of Set 15 | kalaleh
# Processing Record 44 of Set 15 | nehe
# Processing Record 45 of Set 15 | zaysan
# Processing Record 46 of Set 15 | san jose
# Processing Record 47 of Set 15 | lufilufi
# Processing Record 48 of Set 15 | pangnirtung
# Processing Record 49 of Set 15 | sapapalii
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Salalah  17.0151  54.0924     77.09        78          20
# 1       Hermanus -34.4187  19.2345     60.91        89          15
# 2    Kjollefjord  70.9457  27.3465     35.02        86         100
# 3         Iberia  29.9502 -91.7507     70.05        37          75
# 4      Jamestown  42.0970 -79.2353     58.64        67           1
# 5  Sainte-Thecle  46.8168 -72.4991     43.12        83           0
# 6          Conil  44.9673   3.7177     47.68        83          35
# 7    Canyon Lake  29.8752 -98.2625     76.05        28           0
# 8         Shieli  44.1667  66.7500     46.11        58         100
# 9    Katastarion  37.8333  20.7667     49.89        64           6
#
#    Wind Speed Country       Description                 Date
# 0        4.61      OM        few clouds  2021-10-28 23:14:07
# 1        9.06      ZA        few clouds  2021-10-28 23:11:38
# 2       16.28      NO   overcast clouds  2021-10-28 23:14:08
# 3       23.96      US     broken clouds  2021-10-28 23:14:08
# 4       11.50      US         clear sky  2021-10-28 23:13:56
# 5        2.66      CA         clear sky  2021-10-28 23:14:08
# 6       13.69      FR  scattered clouds  2021-10-28 23:14:09
# 7        4.00      US         clear sky  2021-10-28 23:14:09
# 8        6.82      KZ   overcast clouds  2021-10-28 23:14:09
# 9       13.76      GR         clear sky  2021-10-28 23:14:10

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat      Lng  Max Temp  \
# 0        Salalah      OM  2021-10-28 23:14:07  17.0151  54.0924     77.09
# 1       Hermanus      ZA  2021-10-28 23:11:38 -34.4187  19.2345     60.91
# 2    Kjollefjord      NO  2021-10-28 23:14:08  70.9457  27.3465     35.02
# 3         Iberia      US  2021-10-28 23:14:08  29.9502 -91.7507     70.05
# 4      Jamestown      US  2021-10-28 23:13:56  42.0970 -79.2353     58.64
# 5  Sainte-Thecle      CA  2021-10-28 23:14:08  46.8168 -72.4991     43.12
# 6          Conil      FR  2021-10-28 23:14:09  44.9673   3.7177     47.68
# 7    Canyon Lake      US  2021-10-28 23:14:09  29.8752 -98.2625     76.05
# 8         Shieli      KZ  2021-10-28 23:14:09  44.1667  66.7500     46.11
# 9    Katastarion      GR  2021-10-28 23:14:10  37.8333  20.7667     49.89
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        78          20        4.61        few clouds
# 1        89          15        9.06        few clouds
# 2        86         100       16.28   overcast clouds
# 3        37          75       23.96     broken clouds
# 4        67           1       11.50         clear sky
# 5        83           0        2.66         clear sky
# 6        83          35       13.69  scattered clouds
# 7        28           0        4.00         clear sky
# 8        58         100        6.82   overcast clouds
# 9        64           6       13.76         clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
